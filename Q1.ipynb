# %%
import os
import pandas
import csv
import numpy
import numpy as np
import matplotlib
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import tools

df = pandas.read_csv("D:/Code/que-faire-a-paris-.csv", sep= ';', header = 0)
df_propre = df
del df_propre['tags']
df_propre.dropna(how= 'all', inplace= True)
df_propre.fillna('', inplace= True)

df_propre.drop(columns = ["url"], axis = 1, inplace = True)

#df_propre.drop(df_propre.columns.difference(['id', 'title', 'date_start', 'date_end', 'tags', 'address_name', 'address_street', 'address_zipcode', 'lat_lon', 'price_type']


print(df_propre)
# Out:
#                                                   title  \
# 0                          Premiers Pas en ART-THÉRAPIE
# 1                                     SOIRÉE DE CLÔTURE
# 2     Perennial Fashion (Presence Falling) – Une lec...
# 3     Le 14 février, fêtez la St Valentin avec vos a...
# 4        La Jam du Lundi animée par François Constantin
# ...                                                 ...
# 2118  Atelier de sérigraphie sur taoru (serviette tr...
# 2119                Requiem de Mozart & Boléro de Ravel
# 2120  Parranda La Cruz + Mazalada en concert à FGO-B...
# 2121  Le quốc-ngữ. L'écriture romanisée, vecteur d'u...
# 2122               Pour sortir au jour - Olivier Dubois
#
#                                               lead_text  \
# 0     Venez participer à une série de 5 ateliers d'a...
# 1     Deux spectacles : POLYESTER de Margot Alexandr...
# 2     Perennial Fashion (Presence Falling) – Une lec...
# 3     Parce qu'à la St Valentin, la fête ne doit pas...
# 4     Les Jams du lundi sont LE Rendez-vous incontou...
# ...                                                 ...
# 2118  Une collaboration FWELLS x TAORU - découvrir l...
# 2119  Venez assister au Requiem de Mozart et au Bolé...
# 2120  Parranda La Cruz et Mazalada, deux groupes exc...
# 2121  La diffusion de l'écriture romanisée permet de...
# 2122  Le solo de danse d'Olivier Dubois dans le cadr...
#
#                                             description  \
# 0     <p>L’art-thérapie est un moyen ludique et créa...
# 1     <p><strong>Deux spectacles, un concert de tang...
# 2     <p>A l’occasion de son passage par Paris dans ...
# 3     <p>Le 14 février c'est la St Valentin, c'est c...
# 4     <p>Au Baiser Salé, on connait François Constan...
# ...                                                 ...
# 2118  <h2>Initiez-vous à la sérigraphie et créez une...
# 2119  <h3>Requiem de Mozart &amp; Boléro de Ravel</h...
# 2120  <h2>PARRANDA LA CRUZ</h2><p>Parranda La Cruz v...
# 2121  <p>Le Vietnam est le seul pays asiatique à avo...
# 2122  <p>À 50 ans, en slip et \ncravate ou manteau d...
#
#                      date_start                   date_end  \
# 0
# 1
# 2
# 3
# 4     2023-05-02T00:00:00+02:00  2023-05-02T05:00:00+02:00
# ...                         ...                        ...
# 2118  2023-04-15T17:00:00+02:00  2023-04-15T19:30:00+02:00
# 2121  Collections de la BULAC, BIULO PER.2894.  ...
# 2122                                     libre  ...
#
#                      updated_at  \
# 0     2022-01-03T10:07:49+01:00
# 1     2022-01-11T18:37:41+01:00
# 2     2022-02-03T14:52:19+01:00
# 3     2022-02-14T10:29:09+01:00
# 4     2022-06-30T10:37:43+02:00
# ...                         ...
# 2118  2023-03-23T15:41:03+01:00
# 2119  2023-03-23T15:41:33+01:00
# 2120  2023-03-23T15:47:35+01:00
# 2121  2023-03-24T09:53:20+01:00
# 2122  2023-03-24T10:05:44+01:00
#
#                                        image_couverture  \
# 0     https://opendata.paris.fr/api/v2/catalog/datas...
# 1     https://opendata.paris.fr/api/v2/catalog/datas...
# 2     https://opendata.paris.fr/api/v2/catalog/datas...
# 3     https://opendata.paris.fr/api/v2/catalog/datas...
# 4     https://opendata.paris.fr/api/v2/catalog/datas...
# ...                                                 ...
# 2118  https://opendata.paris.fr/api/v2/catalog/datas...
# 2119  https://opendata.paris.fr/api/v2/catalog/datas...
# 2120  https://opendata.paris.fr/api/v2/catalog/datas...
# 2121  https://opendata.paris.fr/api/v2/catalog/datas...
# 2122  https://opendata.paris.fr/api/v2/catalog/datas...
#
#                                                programs address_url  \
# 0
# 1     BRUIT - Festival théâtre et musique (https://w...
# 2
# 3
# 4
# ...                                                 ...         ...
# 2118
# 2119
# 2120
# 2121
# 2122
#
#      address_url_text address_text  \
# 0
# 1
# 2
# 3
# 4
# ...               ...          ...
# 2118
# 2119
# 2120
# 2121
# 2122
#
#                                             title_event  \
# 0                          Premiers Pas en ART-THÉRAPIE
# 1     THÉÂTRE DANSE CONCERT dans le cadre de BRUIT -...
# 2     Perennial Fashion (Presence Falling) – Une lec...
# 3                                             St Weezem
# 4
# ...                                                 ...
# 2118  Inédit à Paris : sérigraphie sur serviette jap...
# 2119                Requiem de Mozart & Boléro de Ravel
# 2120
# 2121
# 2122
#
#                                                audience childrens  \
# 0     Public  adolescents adultes. A partir de 16 an...
# 1                                          Tout public.
# 2                                      Public  adultes.
# 3                                      Public  adultes.
# 4                                          Tout public.
# ...                                                 ...       ...
# 2118  Public  adolescents adultes. A partir de 10 an...
# 2119                                       Tout public.
# 2120                                   Public  adultes.
# 2121                       Public  adolescents adultes.
# 2122   Public  adolescents adultes. A partir de 12 ans.
#
#      contributor_group
# 0          Internautes
# 1          Internautes
# 2               Agenda
# 3          Internautes
# 4               Agenda
# ...                ...
# 2118       Internautes
# 2119            Agenda
# 2120            Agenda
# 2121            Agenda
# 2122            Agenda
#
# [2123 rows x 39 columns]
